# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv("tracks.csv")

# %%
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
#Null values
df_tracks.isnull().mean()*100
# Out:
# id                  0.000000
# name                0.012102
# popularity          0.000000
# duration_ms         0.000000
# explicit            0.000000
# artists             0.000000
# id_artists          0.000000
# release_date        0.000000
# danceability        0.000000
# energy              0.000000
# key                 0.000000
# loudness            0.000000
# mode                0.000000
# speechiness         0.000000
# acousticness        0.000000
# instrumentalness    0.000000
# liveness            0.000000
# valence             0.000000
# tempo               0.000000
# time_signature      0.000000
# dtype: float64

# %%
df_tracks.sort_values('popularity', ascending = True).head(10)
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
df_tracks.sort_values('popularity', ascending = False).head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
# 92819  1xK1Gg9SxG8fy2Ya373oqb                                 Bandido
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
df_tracks.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
#Columns containing numeric datatypes
numeric= df_tracks.select_dtypes(include= np.number).columns
#Columns containing object datatypes
Categorical= df_tracks.select_dtypes(include= ['object']).columns

# %%
for i in numeric:
    sns.distplot(df[numeric])
plt.show()
# Out:
# C:\Users\death\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\death\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
most_popular = df_tracks.query('popularity>90', inplace= False).sort_values('popularity', ascending= False)
most_popular[:10]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
sns.distplot(df['popularity'])
# Out:
# C:\Users\death\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='popularity', ylabel='Density'>

# %%
df_tracks.set_index("release_date", inplace= True)
df_tracks.index= pd.to_datetime(df_tracks.index)
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %%
#Filtering for values using iloc
df_tracks[["artists"]].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922-01-01 00:00:00, dtype: object

# %%
df_tracks["duration"]=df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms", inplace=True, axis=1)

# %%
df_tracks.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
# Name: duration, dtype: int64

# %%
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %%
df_tracks["duration"]
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 586672, dtype: int64

# %%
df_tracks.groupby(['release_date'])['id'].value_counts()
# Out:
# release_date  id
# 1900-01-01    74CSJTE5QQp1e4bHzm3wti    1
# 1922-01-01    08Uvbd5B1zmoqcwciiEMYe    1
#               08y9GfoqCWfOGsKdwojr5e    1
#               09qgL5pkqhgNbehgrFwQdL    1
#               0AE4k441ynT8X0jZxTVKkW    1
#                                        ..
# 2021-04-16    7siJOvQqsdJxTLJBDUgbJ1    1
#               7uHMx3E8in607GoKRv1Kcx    1
#               7vowikaFigYIhnuOrt8KBJ    1
#               7xA6SBhYuLBPIS2LUED7O7    1
#               7y60nwnOXGAn8E50yZPSYT    1
# Name: id, Length: 586672, dtype: int64

# %%
df_tracks['time_signature'].max()
# Out:
# 5

# %%
df= df_tracks.assign(time_group=pd.cut(df_tracks[ 'time_signature'], bins = 10))
df['release_date']= pd.to_datetime(df['release_date'])

# %%
df= df.assign(year= pd.cut(df['release_date'].dt.year, bins = 10))

# %%
df.groupby(['year','time_group'])['popularity'].describe()
# Out:
#                                      count       mean        std   min   25%  \
# year               time_group
# (1899.879, 1912.1] (3.5, 4.0]          1.0  19.000000        NaN  19.0  19.0
# (1912.1, 1924.2]   (3.5, 4.0]       1031.0   1.327837   4.224201   0.0   0.0
#                    (-0.005, 0.5]       3.0   0.333333   0.577350   0.0   0.0
#                    (0.5, 1.0]         67.0   0.074627   0.610847   0.0   0.0
#                    (2.5, 3.0]        368.0   0.171196   1.435455   0.0   0.0
#                    (4.5, 5.0]        115.0   0.008696   0.093250   0.0   0.0
# (1924.2, 1936.3]   (3.5, 4.0]      10994.0   1.875296   5.104280   0.0   0.0
#                    (-0.005, 0.5]      16.0   0.187500   0.750000   0.0   0.0
#                    (0.5, 1.0]        377.0   1.339523   4.706419   0.0   0.0
#                    (2.5, 3.0]       2774.0   1.268205   4.173416   0.0   0.0
#                    (4.5, 5.0]        713.0   1.311360   4.514160   0.0   0.0
# ...

# %%
df= df_tracks.assign(time_group=pd.cut(df_tracks[ 'time_signature'], bins = 10))
df``

# %%
corr_df=df_tracks.drop(["key", "mode", "explicit"], axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap= sns.heatmap(corr_df, annot= True, fmt= ".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidth=1, linecolor= "Black")
heatmap.set_title("Correlation HeatMap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, 'popularity'),
#  Text(1.5, 0, 'danceability'),
#  Text(2.5, 0, 'energy'),
#  Text(3.5, 0, 'loudness'),
#  Text(4.5, 0, 'speechiness'),
#  Text(5.5, 0, 'acousticness'),
#  Text(6.5, 0, 'instrumentalness'),
#  Text(7.5, 0, 'liveness'),
#  Text(8.5, 0, 'valence'),
#  Text(9.5, 0, 'tempo'),
#  Text(10.5, 0, 'time_signature'),
#  Text(11.5, 0, 'duration')]

# %%
sample_df = df_tracks.sample(int(0.004*len(df_tracks)))
len(sample_df)
# Out:
# 2346

# %%
plt.figure(figsize= (10,6))
sns.regplot(data= sample_df, y= "loudness", x= "energy", color= "c").set(title= "loudness vs energy correlation")
# Out:
# [Text(0.5, 1.0, 'loudness vs energy correlation')]

# %%
plt.figure(figsize= (10,6))
sns.regplot(data= sample_df, y= "danceability", x= "acousticness", color= "b").set(title= "loudness vs energy correlation")
# Out:
# [Text(0.5, 1.0, 'loudness vs energy correlation')]

# %%
plt.figure(figsize= (10,6))
sns.regplot(data= sample_df, y= "energy", x= "valence", color= "b").set(title= "loudness vs energy correlation")
# Out:
# [Text(0.5, 1.0, 'loudness vs energy correlation')]

# %%
sample_df.head()
# Out:
#                             id  \
# 245459  7w5eSfDMN9Yc0FAkKT6ByO
# 13445   2wke5oNlPUAc3wAcxXXn7Y
# 276450  1Mo0SAAtmC5wlHwbTGFCI5
# 453024  3QbWmNihIQScYJzdnPsFj3
# 184098  7zwpaW9fJihaoq0EK9XKgv
#
#                                                      name  popularity  \
# 245459                    Sugebėt Pasikeist - Bonus Track          33
# 13445               Spellbound (1945) Spellbound Concerto           0
# 276450                                   風生水起 (feat. 麥玲玲)          23
# 453024  Matthäus-Passion, BWV 244 / Erster Teil: No. 2...          27
# 184098                 Silvergun Superman - 2019 Remaster          43
#
#         explicit                                            artists  \
# 245459         0                                            ['ba.']
# 13445          0       ['Miklós Rózsa', 'Hollywood Bowl Orchestra']
# 276450         0                                           ['Fama']
# 453024         0  ['Johann Sebastian Bach', 'English Baroque Sol...
# ...

# %%
df_tracks["dates"]= df_tracks.index.get_level_values("release_date")
df_tracks.dates= pd.to_datetime(df_tracks.dates)
years= df_tracks.dates.dt.year

# %%
df_tracks["dates"]= pd.to_datetime(df_tracks["release_date"])

# %%
years= df_tracks.dates.dt.year

# %%
pip install --user seaborn==0.11.0
# Out:
# ...
#
# ...

# %%
sns.displot(years, aspect=2, height=5, kind="hist").set(title= "No of songs per year")

# %%
total_dr
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 586672, dtype: int64

# %%
total_dr= df_tracks.duration
fig_dims= (18,7)
fig, ax= plt.subplots(figsize= fig_dims)
fig= sns.barplot(data= None, x= years, y= total_dr, ax = ax, errwidth= False).set("Year vs duration")
plt.xticks(rotation= 90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [131], in <cell line: 4>()
#       2 fig_dims= (18,7)
#       3 fig, ax= plt.subplots(figsize= fig_dims)
# ----> 4 fig= sns.barplot(data= None, x= years, y= total_dr, ax = ax, errwidth= False).set("Year vs duration")
#       5 plt.xticks(rotation= 90)
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
total_dr= df_tracks.duration
sns.set_style(style = "whitegrid")
fig_dims = (10,5)
fig, ax= plt.subplots(figsize= fig_dims)
fig= sns.lineplot(x= years, y=total_dr, ax=ax).set(title= "Years vs Duration")
plt.xticks(rotation= 60)
# Out:
# (array([1880., 1900., 1920., 1940., 1960., 1980., 2000., 2020., 2040.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df_genre= pd.read_csv("SpotifyFeatures.csv")

# %%
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
plt.figure(figsize=(18,10))
plt.title("Duration of the songs in Different Genres")
sns.color_palette("rocket", as_cmap= True)
sns.barplot(y="genre", x="duration_ms", data= df_genre)
plt.xlabel("Duration in milli seconds")
plt.ylabel("Genres")
# Out:
# Text(0, 0.5, 'Genres')

# %%
sns.set_style(style= "darkgrid")
plt.figure(figsize=(12,10))
famous= df_genre.sort_values("popularity", ascending= False).head(10)
sns.barplot(y= "genre", x="popularity", data= famous).set(title= "Top 5 Genres based on popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres based on popularity')]

# %%
famous
# Out:
#             genre    artist_name                                track_name  \
# 9027        Dance  Ariana Grande                                   7 rings
# 107804        Pop  Ariana Grande                                   7 rings
# 86951         Rap    Post Malone                                      Wow.
# 107803        Pop    Post Malone                                      Wow.
# 107802        Pop  Ariana Grande  break up with your girlfriend, i'm bored
# 9026        Dance  Ariana Grande  break up with your girlfriend, i'm bored
# 66643     Hip-Hop   Daddy Yankee                                 Con Calma
# 107909        Pop   Daddy Yankee                                 Con Calma
# 138918  Reggaeton   Daddy Yankee                                 Con Calma
# 107829        Pop        Ava Max                          Sweet but Psycho
#
#                       track_id  popularity  acousticness  danceability  \
# ...
